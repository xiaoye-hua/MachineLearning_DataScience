# %% [markdown]
# # Gensim Word2Vec Tutorial

# %% [markdown]
# <img src="https://images.freeimages.com/images/large-previews/2b9/letters-1-yes-1188348.jpg" alt="drawing" width="350"/>

# %% [markdown]
# # Motivation
#
# As I started working at [Supportiv](http://www.supportiv.com), the support network for instant peer support, a few months ago, I began looking into Language Models and Word2Vec particularly. A python native, I naturally decided to focus on Gensim's implementation of Word2Vec, and went on to look for tutorials on the web. As all good data scientists, I directly applied and reproduced the code samples from multiple website. Confused and often disappointed by the results I got, I went deeper and deeper, from stackoverflow threads, to Gensim's Google Groups, onto the documentation of the library, to try and understand what went wrong in my approach. After weeks of hard labor, I finally managed to get decent results, but I was frustrated by these online tutorials which were, for the most part, misleading.
#
# What troubled me the most in these online tutorials was their mismanagement of the model training: the code worked, and I got results which appeared to be decent at first, but the more I looked into them, the more disturbing they were. I wasted a lot of time figuring out what was wrong.
#
# Another issue I had with these tutorials was the data preparation step: too often, the authors chose to load an existing preprocessed dataset, use a toy example or skip this part. However, I always thought that one of the most important parts of the creation of a Word2Vec model was then missing. During my experimentations, I noticed that lemmatizing the sentences or looking for phrases/bigrams in them had a big impact over the results and performance of my models. Though the influence of the preprocessing varies with each dataset and application, I thought I would include the data preparation steps in this tutorial and use the great spaCy library along with it.
#
# I am not the only one annoyed by some of these [issues](https://groups.google.com/d/msg/gensim/jom4JFt7EV8/y5fjhupbAgAJ), so I decided to write my own tutorial.
#
# I do not pledge that it is perfect, nor the best way to implement Word2Vec, simply that it is better than a good chunk of what is out there 😉

# %% [markdown]
# # Plan
#
# 1. [Briefing about Word2Vec](#Briefing-about-Word2Vec:)
#     * [Purpose of the tutorial](#Purpose-of-the-tutorial:)
#     * [Brief explanation](#Brief-explanation:)
#
# 2. [Getting Started](#Getting-Started)
#     * [Setting up the environment](#Setting-up-the-environment:)
#     * [The data](#The-data:)
# 3. [Preprocessing](#Preprocessing)
#     * [Cleaning](#Cleaning)
#     * [Bigrams](#Bigrams)
#     * [Most frequent words](#Most-Frequent-Words)
#
# 4. [Training the Model](#Training-the-model)
#     * [Gensim Word2Vec Implementation](#Gensim-Word2Vec-Implementation:)
#     * [Why I seperate the training of the model in 3 steps](#Why-I-seperate-the-training-of-the-model-in-3-steps:)
#     * [Training the model](#Training-the-model)
#         * [The parameters](#The-parameters)
#         * [Building the vocabulary table](#Building-the-Vocabulary-Table)
#         * [Training of the model](#Training-of-the-model)
#         * [Saving the model](#Saving-the-model:)
# 5. [Exploring the Model](#Exploring-the-model)
#     * [Most similar to](#Most-similar-to:)
#     * [Similarities](#Similarities:)
#     * [Odd-one-out](#Odd-One-Out:)
#     * [Analogy difference](#Analogy-difference:)
#     * [t-SNE visualizations](#t-SNE-visualizations:)
#         * [10 Most similar words vs. 8 Random words](#10-Most-similar-words-vs.-8-Random-words:)
#         * [10 Most similar words vs. 10 Most dissimilar](#10-Most-similar-words-vs.-10-Most-dissimilar:)
#         * [10 Most similar words vs. 11th to 20th Most similar words](#10-Most-similar-words-vs.-11th-to-20th-Most-similar-words:)
# 6. [Final Thoughts](#Final-Thoughts)
# 7. [Material for more in depths understanding](#Material-for-more-in-depths-understanding:)
# 8. [Acknowledgements](#Acknowledgements)
# 9. [References](#References:)
# 10. [End](#End)

# %% [markdown]
# # Briefing about Word2Vec:
#
# <img src="http://mccormickml.com/assets/word2vec/skip_gram_net_arch.png" alt="drawing" width="550"/>
#
# [[1]](#References:)
#
#
# ## Purpose of the tutorial:
# As I said before, this tutorial focuses on the right use of the Word2Vec package from the Gensim libray; therefore, I am not going to explain the concepts and ideas behind Word2Vec here. I am simply going to give a very brief explanation, and provide you with links to good, in depth tutorials.
#
# ## Brief explanation:
#
# Word2Vec was introduced in two [papers](#Material-for-more-in-depths-understanding:) between September and October 2013, by a team of researchers at Google. Along with the papers, the researchers published their implementation in C. The Python implementation was done soon after the 1st paper, by [Gensim](https://radimrehurek.com/gensim/index.html).
#
# The underlying assumption of Word2Vec is that two words sharing similar contexts also share a similar meaning and consequently a similar vector representation from the model. For instance: "dog", "puppy" and "pup" are often used in similar situations, with similar surrounding words like "good", "fluffy" or "cute", and according to Word2Vec they will therefore share a similar vector representation.<br>
#
# From this assumption, Word2Vec can be used to find out the relations between words in a dataset, compute the similarity between them, or use the vector representation of those words as input for other applications such as text classification or clustering.
#
# # Getting Started
#
# ## Setting up the environment:
#
# `python==3.6.3`
#
# Libraries used:
#  * `xlrd==1.1.0`: https://pypi.org/project/xlrd/
#  * `spaCy==2.0.12`: https://spacy.io/usage/
#  * `gensim==3.4.0`: https://radimrehurek.com/gensim/install.html
#  * `scikit-learn==0.19.1`: http://scikit-learn.org/stable/install.html
#  * `seaborn==0.8`: https://seaborn.pydata.org/installing.html

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/44/Logo_The_Simpsons.svg" alt="drawing" width="400"/>
#
# ## The data:
# I chose to play with the script from the Simpsons, both because I love the Simpsons and because with more than 150k lines of dialogues, the dataset was substantial!
#
# This dataset contains the characters, locations, episode details, and script lines for approximately 600 Simpsons episodes, dating back to 1989. It can be found here: https://www.kaggle.com/ambarish/fun-in-text-mining-with-simpsons/data (~25MB)

# %% [markdown]
# # Preprocessing
#
# We keep only two columns:
# * `raw_character_text`: the character who speaks (can be useful when monitoring the preprocessing steps)
# * `spoken_words`: the raw text from the line of dialogue
#
# We do not keep `normalized_text` because we want to do our own preprocessing.
#
# You can find the resulting file here: https://www.kaggle.com/pierremegret/dialogue-lines-of-the-simpsons

# %%
df = pd.read_csv('../input/simpsons_dataset.csv')
df.shape
# Out:
# (158314, 2)

# %%
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %% [markdown]
# The missing values comes from the part of the script where something happens, but with no dialogue. For instance "(Springfield Elementary School: EXT. ELEMENTARY - SCHOOL PLAYGROUND - AFTERNOON)"

# %%
df.isnull().sum()
# Out:
# raw_character_text    17814
# spoken_words          26459
# dtype: int64

# %% [markdown]
# Removing the missing values:

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# raw_character_text    0
# spoken_words          0
# dtype: int64

# %%
df.shape
# Out:
# (131853, 2)

# %% [markdown]
# ## Cleaning:
# We are lemmatizing and removing the stopwords and non-alphabetic characters for each line of dialogue.

# %%
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %%
nlp = spacy.load('en', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %% [markdown]
# Removes non-alphabetic characters:

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['spoken_words'])

# %%
# print(brief_cleaning)

# %% [markdown]
# Taking advantage of spaCy .pipe() attribute to speed-up the cleaning process:

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 2.14 mins

# %% [markdown]
# Put the results in a DataFrame to remove missing values and duplicates:

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (92412, 1)

# %%
df_clean.sample(3)
# Out:
#                                                     clean
# 122819  not think oath yes father create flatulent fox...
# 41816                                  be amazed be alive
# 96004                    be go help idea hideous creature

# %% [markdown]
# ## Bigrams:
# We are using Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences.
# https://radimrehurek.com/gensim/models/phrases.html
#
# The main reason we do this is to catch words like "mr_burns" or "bart_simpson" !

# %%
from gensim.models.phrases import Phrases, Phraser
# Out:
# INFO - 06:01:48: 'pattern' package not found; tag filters are not available for English

# %% [markdown]
# As `Phrases()` takes a list of list of words as input:

# %%
sent = [row.split() for row in df_clean['clean']]

# %% [markdown]
# Creates the relevant phrases from the list of sentences:

# %%
# sent

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# INFO - 06:02:01: collecting all words and their counts
# INFO - 06:02:01: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 06:02:01: PROGRESS: at sentence #10000, processed 67396 words and 50551 word types
# INFO - 06:02:02: PROGRESS: at sentence #20000, processed 140465 words and 95808 word types
# INFO - 06:02:02: PROGRESS: at sentence #30000, processed 207950 words and 132011 word types
# INFO - 06:02:02: PROGRESS: at sentence #40000, processed 270207 words and 164407 word types
# INFO - 06:02:02: PROGRESS: at sentence #50000, processed 334085 words and 196195 word types
# INFO - 06:02:02: PROGRESS: at sentence #60000, processed 400877 words and 228659 word types
# INFO - 06:02:02: PROGRESS: at sentence #70000, processed 467802 words and 260712 word types
# INFO - 06:02:03: PROGRESS: at sentence #80000, processed 534361 words and 292095 word types
# INFO - 06:02:03: PROGRESS: at sentence #90000, processed 602037 words and 321944 word types
# INFO - 06:02:03: collected 328658 word types from a corpus of 618920 words (unigram + bigrams) and 92412 sentences
# INFO - 06:02:03: using 328658 counts as vocab in Phrases<0 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>

# %% [markdown]
# The goal of Phraser() is to cut down memory consumption of Phrases(), by discarding model state not strictly needed for the bigram detection task:

# %%
bigram = Phraser(phrases)
# Out:
# INFO - 06:02:03: source_vocab length 328658
# INFO - 06:02:07: Phraser built with 127 phrasegrams

# %% [markdown]
# Transform the corpus based on the bigrams detected:

# %%
sentences = bigram[sent]

# %% [markdown]
# ## Most Frequent Words:
# Mainly a sanity check of the effectiveness of the lemmatization, removal of stopwords, and addition of bigrams.

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 29673

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['be', 'not', 'oh', 'will', 'like', "'s", 'know', 'think', 'hey', 'good']

# %% [markdown]
# # Training the model
# ## Gensim Word2Vec Implementation:
# We use Gensim implementation of word2vec: https://radimrehurek.com/gensim/models/word2vec.html

# %%
import multiprocessing

from gensim.models import Word2Vec

# %% [markdown]
# ## Why I seperate the training of the model in 3 steps:
# I prefer to separate the training in 3 distinctive steps for clarity and monitoring.
# 1. `Word2Vec()`:
# >In this first step, I set up the parameters of the model one-by-one. <br>I do not supply the parameter `sentences`, and therefore leave the model uninitialized, purposefully.
# 2. `.build_vocab()`:
# >Here it builds the vocabulary from a sequence of sentences and thus initialized the model. <br>With the loggings, I can follow the progress and even more important, the effect of `min_count` and `sample` on the word corpus. I noticed that these two parameters, and in particular `sample`, have a great influence over the performance of a model. Displaying both allows for a more accurate and an easier management of their influence.
# 3. `.train()`:
# >Finally, trains the model.<br>
# The loggings here are mainly useful for monitoring, making sure that no threads are executed instantaneously.

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
cores
# Out:
# 4

# %% [markdown]
# ## The parameters:
#
# * `min_count` <font color='purple'>=</font> <font color='green'>int</font> - Ignores all words with total absolute frequency lower than this - (2, 100)
#
#
# * `window` <font color='purple'>=</font> <font color='green'>int</font> - The maximum distance between the current and predicted word within a sentence. E.g. `window` words on the left and `window` words on the left of our target - (2, 10)
#
#
# * `size` <font color='purple'>=</font> <font color='green'>int</font> - Dimensionality of the feature vectors. - (50, 300)
#
#
# * `sample` <font color='purple'>=</font> <font color='green'>float</font> - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial.  - (0, 1e-5)
#
#
# * `alpha` <font color='purple'>=</font> <font color='green'>float</font> - The initial learning rate - (0.01, 0.05)
#
#
# * `min_alpha` <font color='purple'>=</font> <font color='green'>float</font> - Learning rate will linearly drop to `min_alpha` as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
#
#
# * `negative` <font color='purple'>=</font> <font color='green'>int</font> - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
#
#
# * `workers` <font color='purple'>=</font> <font color='green'>int</font> - Use these many worker threads to train the model (=faster training with multicore machines)

# %%
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %% [markdown]
# ## Building the Vocabulary Table:
# Word2Vec requires us to build the vocabulary table (simply digesting all the words and filtering out the unique words, and doing some basic counts on them):

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 06:03:14: collecting all words and their counts
# INFO - 06:03:14: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 06:03:15: PROGRESS: at sentence #10000, processed 65193 words, keeping 9096 word types
# INFO - 06:03:15: PROGRESS: at sentence #20000, processed 136024 words, keeping 13916 word types
# INFO - 06:03:15: PROGRESS: at sentence #30000, processed 201577 words, keeping 16865 word types
# INFO - 06:03:16: PROGRESS: at sentence #40000, processed 262082 words, keeping 19506 word types
# INFO - 06:03:16: PROGRESS: at sentence #50000, processed 324069 words, keeping 21758 word types
# INFO - 06:03:16: PROGRESS: at sentence #60000, processed 388895 words, keeping 23910 word types
# INFO - 06:03:17: PROGRESS: at sentence #70000, processed 454042 words, keeping 25876 word types
# INFO - 06:03:17: PROGRESS: at sentence #80000, processed 518929 words, keeping 27769 word types
# INFO - 06:03:17: PROGRESS: at sentence #90000, processed 584755 words, keeping 29345 word types
# INFO - 06:03:17: collected 29673 word types from a corpus of 601119 raw words and 92412 sentences
# INFO - 06:03:17: Loading a fresh vocabulary
# INFO - 06:03:17: effective_min_count=20 retains 3375 unique words (11% of original 29673, drops 26298)
# INFO - 06:03:17: effective_min_count=20 leaves 515089 word corpus (85% of original 601119, drops 86030)
# INFO - 06:03:17: deleting the raw counts dictionary of 29673 items
# INFO - 06:03:17: sample=6e-05 downsamples 1080 most-common words
# INFO - 06:03:17: downsampling leaves estimated 219321 word corpus (42.6% of prior 515089)
# INFO - 06:03:17: estimated required memory for 3375 words and 300 dimensions: 9787500 bytes
# INFO - 06:03:17: resetting layer weights
# Time to build vocab: 0.05 mins

# %%
# w2v.cor

# %% [markdown]
# ## Training of the model:
# _Parameters of the training:_
# * `total_examples` <font color='purple'>=</font> <font color='green'>int</font> - Count of sentences;
# * `epochs` <font color='purple'>=</font> <font color='green'>int</font> - Number of iterations (epochs) over the corpus - [10, 20, 30]

# %%
w2v_model.corpus_count
# Out:
# 92412

# %%
w2v_model.corpus_total_words
# Out:
# 601119

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 06:04:08: training model with 3 workers on 3375 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2
# INFO - 06:04:09: EPOCH 1 - PROGRESS: at 30.45% examples, 68271 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:10: EPOCH 1 - PROGRESS: at 65.09% examples, 69460 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:11: EPOCH 1 - PROGRESS: at 93.44% examples, 67050 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:11: EPOCH - 1 : training on 601119 raw words (219268 effective words) took 3.3s, 67237 effective words/s
# INFO - 06:04:12: EPOCH 2 - PROGRESS: at 30.45% examples, 68980 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:13: EPOCH 2 - PROGRESS: at 61.73% examples, 66896 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:14: EPOCH 2 - PROGRESS: at 86.72% examples, 63031 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:15: EPOCH - 2 : training on 601119 raw words (219459 effective words) took 3.4s, 63966 effective words/s
# INFO - 06:04:16: EPOCH 3 - PROGRESS: at 30.45% examples, 68051 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:17: EPOCH 3 - PROGRESS: at 60.07% examples, 63716 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:18: EPOCH 3 - PROGRESS: at 91.80% examples, 65699 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:18: EPOCH - 3 : training on 601119 raw words (218941 effective words) took 3.3s, 66473 effective words/s
# INFO - 06:04:19: EPOCH 4 - PROGRESS: at 30.45% examples, 66423 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:20: EPOCH 4 - PROGRESS: at 65.09% examples, 68657 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:21: EPOCH 4 - PROGRESS: at 96.63% examples, 69070 words/s, in_qsize 1, out_qsize 0
# INFO - 06:04:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:21: EPOCH - 4 : training on 601119 raw words (219933 effective words) took 3.2s, 69204 effective words/s
# INFO - 06:04:22: EPOCH 5 - PROGRESS: at 28.77% examples, 59559 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:24: EPOCH 5 - PROGRESS: at 63.43% examples, 64661 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:25: EPOCH 5 - PROGRESS: at 96.63% examples, 66329 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:25: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:25: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:25: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:25: EPOCH - 5 : training on 601119 raw words (219201 effective words) took 3.3s, 67021 effective words/s
# INFO - 06:04:26: EPOCH 6 - PROGRESS: at 30.45% examples, 66936 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:27: EPOCH 6 - PROGRESS: at 65.09% examples, 69488 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:28: EPOCH 6 - PROGRESS: at 98.21% examples, 70101 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:28: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:28: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:28: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:28: EPOCH - 6 : training on 601119 raw words (219677 effective words) took 3.1s, 70474 effective words/s
# INFO - 06:04:29: EPOCH 7 - PROGRESS: at 27.07% examples, 58469 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:30: EPOCH 7 - PROGRESS: at 60.07% examples, 63188 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:31: EPOCH 7 - PROGRESS: at 91.80% examples, 65126 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:31: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:31: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:31: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:31: EPOCH - 7 : training on 601119 raw words (219546 effective words) took 3.4s, 65409 effective words/s
# INFO - 06:04:32: EPOCH 8 - PROGRESS: at 32.16% examples, 69332 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:33: EPOCH 8 - PROGRESS: at 66.81% examples, 69987 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:34: EPOCH 8 - PROGRESS: at 95.04% examples, 67334 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:34: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:34: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:34: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:34: EPOCH - 8 : training on 601119 raw words (219363 effective words) took 3.2s, 67514 effective words/s
# INFO - 06:04:35: EPOCH 9 - PROGRESS: at 30.45% examples, 66287 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:36: EPOCH 9 - PROGRESS: at 63.43% examples, 66855 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:38: EPOCH 9 - PROGRESS: at 95.04% examples, 67162 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:38: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:38: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:38: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:38: EPOCH - 9 : training on 601119 raw words (219047 effective words) took 3.2s, 67412 effective words/s
# INFO - 06:04:39: EPOCH 10 - PROGRESS: at 30.45% examples, 66285 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:40: EPOCH 10 - PROGRESS: at 60.07% examples, 64120 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:41: EPOCH 10 - PROGRESS: at 93.44% examples, 66575 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:41: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:41: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:41: EPOCH - 10 : training on 601119 raw words (219194 effective words) took 3.3s, 66929 effective words/s
# INFO - 06:04:42: EPOCH 11 - PROGRESS: at 30.45% examples, 65621 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:43: EPOCH 11 - PROGRESS: at 65.09% examples, 67425 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:44: EPOCH 11 - PROGRESS: at 96.63% examples, 68120 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:44: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:44: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:44: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:44: EPOCH - 11 : training on 601119 raw words (219482 effective words) took 3.2s, 68282 effective words/s
# INFO - 06:04:45: EPOCH 12 - PROGRESS: at 22.26% examples, 51212 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:46: EPOCH 12 - PROGRESS: at 51.75% examples, 55989 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:47: EPOCH 12 - PROGRESS: at 83.30% examples, 59617 words/s, in_qsize 1, out_qsize 0
# INFO - 06:04:48: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:48: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:48: EPOCH - 12 : training on 601119 raw words (219283 effective words) took 3.6s, 61478 effective words/s
# INFO - 06:04:49: EPOCH 13 - PROGRESS: at 30.45% examples, 66850 words/s, in_qsize 1, out_qsize 0
# INFO - 06:04:50: EPOCH 13 - PROGRESS: at 65.09% examples, 69335 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:51: EPOCH 13 - PROGRESS: at 96.63% examples, 67557 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:51: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:51: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:51: EPOCH - 13 : training on 601119 raw words (219163 effective words) took 3.2s, 67674 effective words/s
# INFO - 06:04:52: EPOCH 14 - PROGRESS: at 32.16% examples, 69522 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:53: EPOCH 14 - PROGRESS: at 66.81% examples, 70136 words/s, in_qsize 1, out_qsize 0
# INFO - 06:04:54: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:54: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:54: EPOCH - 14 : training on 601119 raw words (219808 effective words) took 3.1s, 71381 effective words/s
# INFO - 06:04:55: EPOCH 15 - PROGRESS: at 32.16% examples, 70104 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:56: EPOCH 15 - PROGRESS: at 66.81% examples, 70615 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:57: EPOCH 15 - PROGRESS: at 96.63% examples, 68160 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:04:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:04:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:04:57: EPOCH - 15 : training on 601119 raw words (219285 effective words) took 3.2s, 68455 effective words/s
# INFO - 06:04:58: EPOCH 16 - PROGRESS: at 30.45% examples, 66758 words/s, in_qsize 0, out_qsize 0
# INFO - 06:04:59: EPOCH 16 - PROGRESS: at 65.09% examples, 68374 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:00: EPOCH 16 - PROGRESS: at 98.21% examples, 69431 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:00: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:00: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:00: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:00: EPOCH - 16 : training on 601119 raw words (219332 effective words) took 3.1s, 69825 effective words/s
# INFO - 06:05:01: EPOCH 17 - PROGRESS: at 30.45% examples, 67396 words/s, in_qsize 1, out_qsize 0
# INFO - 06:05:02: EPOCH 17 - PROGRESS: at 65.09% examples, 69568 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:04: EPOCH 17 - PROGRESS: at 93.44% examples, 66634 words/s, in_qsize 1, out_qsize 0
# INFO - 06:05:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:04: EPOCH - 17 : training on 601119 raw words (219136 effective words) took 3.3s, 67314 effective words/s
# INFO - 06:05:05: EPOCH 18 - PROGRESS: at 32.16% examples, 70266 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:06: EPOCH 18 - PROGRESS: at 66.81% examples, 69675 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:07: EPOCH 18 - PROGRESS: at 98.41% examples, 69653 words/s, in_qsize 1, out_qsize 1
# INFO - 06:05:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:07: EPOCH - 18 : training on 601119 raw words (219590 effective words) took 3.1s, 70324 effective words/s
# INFO - 06:05:08: EPOCH 19 - PROGRESS: at 30.45% examples, 68550 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:09: EPOCH 19 - PROGRESS: at 58.39% examples, 62572 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:10: EPOCH 19 - PROGRESS: at 90.09% examples, 64626 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:10: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:10: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:10: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:10: EPOCH - 19 : training on 601119 raw words (219133 effective words) took 3.4s, 64803 effective words/s
# INFO - 06:05:11: EPOCH 20 - PROGRESS: at 32.16% examples, 70735 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:12: EPOCH 20 - PROGRESS: at 66.81% examples, 71142 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:13: EPOCH 20 - PROGRESS: at 100.00% examples, 71760 words/s, in_qsize 0, out_qsize 1
# INFO - 06:05:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:13: EPOCH - 20 : training on 601119 raw words (219339 effective words) took 3.1s, 71719 effective words/s
# INFO - 06:05:14: EPOCH 21 - PROGRESS: at 25.38% examples, 58266 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:15: EPOCH 21 - PROGRESS: at 60.07% examples, 64921 words/s, in_qsize 1, out_qsize 0
# INFO - 06:05:16: EPOCH 21 - PROGRESS: at 93.44% examples, 65711 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:17: EPOCH - 21 : training on 601119 raw words (219370 effective words) took 3.3s, 66375 effective words/s
# INFO - 06:05:18: EPOCH 22 - PROGRESS: at 28.77% examples, 62329 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:19: EPOCH 22 - PROGRESS: at 63.43% examples, 65868 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:20: EPOCH 22 - PROGRESS: at 91.80% examples, 64188 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:20: EPOCH - 22 : training on 601119 raw words (219411 effective words) took 3.4s, 64479 effective words/s
# INFO - 06:05:21: EPOCH 23 - PROGRESS: at 32.16% examples, 70328 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:22: EPOCH 23 - PROGRESS: at 66.81% examples, 70613 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:23: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:23: EPOCH 23 - PROGRESS: at 98.41% examples, 70221 words/s, in_qsize 1, out_qsize 1
# INFO - 06:05:23: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:23: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:23: EPOCH - 23 : training on 601119 raw words (219541 effective words) took 3.1s, 70859 effective words/s
# INFO - 06:05:24: EPOCH 24 - PROGRESS: at 30.45% examples, 68360 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:25: EPOCH 24 - PROGRESS: at 65.09% examples, 69135 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:26: EPOCH 24 - PROGRESS: at 93.44% examples, 66645 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:26: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:26: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:26: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:26: EPOCH - 24 : training on 601119 raw words (219026 effective words) took 3.3s, 66813 effective words/s
# INFO - 06:05:27: EPOCH 25 - PROGRESS: at 32.16% examples, 69780 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:28: EPOCH 25 - PROGRESS: at 66.81% examples, 69896 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:29: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:30: EPOCH 25 - PROGRESS: at 98.41% examples, 69828 words/s, in_qsize 1, out_qsize 1
# INFO - 06:05:30: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:30: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:30: EPOCH - 25 : training on 601119 raw words (219369 effective words) took 3.1s, 70551 effective words/s
# INFO - 06:05:31: EPOCH 26 - PROGRESS: at 32.16% examples, 69286 words/s, in_qsize 1, out_qsize 0
# INFO - 06:05:32: EPOCH 26 - PROGRESS: at 65.09% examples, 67955 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:33: EPOCH 26 - PROGRESS: at 95.04% examples, 66759 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:33: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:33: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:33: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:33: EPOCH - 26 : training on 601119 raw words (219095 effective words) took 3.3s, 66916 effective words/s
# INFO - 06:05:34: EPOCH 27 - PROGRESS: at 30.45% examples, 67856 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:35: EPOCH 27 - PROGRESS: at 65.09% examples, 69003 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:36: EPOCH 27 - PROGRESS: at 98.21% examples, 70157 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:36: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:36: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:36: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:36: EPOCH - 27 : training on 601119 raw words (219584 effective words) took 3.1s, 70295 effective words/s
# INFO - 06:05:37: EPOCH 28 - PROGRESS: at 32.16% examples, 69919 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:38: EPOCH 28 - PROGRESS: at 63.43% examples, 65707 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:39: EPOCH 28 - PROGRESS: at 96.63% examples, 67891 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:39: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:39: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:39: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:39: EPOCH - 28 : training on 601119 raw words (219753 effective words) took 3.2s, 68137 effective words/s
# INFO - 06:05:40: EPOCH 29 - PROGRESS: at 32.16% examples, 68006 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:41: EPOCH 29 - PROGRESS: at 66.81% examples, 69568 words/s, in_qsize 1, out_qsize 0
# INFO - 06:05:42: EPOCH 29 - PROGRESS: at 98.21% examples, 69309 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:42: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:42: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:42: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:42: EPOCH - 29 : training on 601119 raw words (219058 effective words) took 3.2s, 69513 effective words/s
# INFO - 06:05:43: EPOCH 30 - PROGRESS: at 32.16% examples, 69848 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:44: EPOCH 30 - PROGRESS: at 60.07% examples, 63727 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:45: EPOCH 30 - PROGRESS: at 91.80% examples, 65528 words/s, in_qsize 0, out_qsize 0
# INFO - 06:05:46: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:05:46: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:05:46: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:05:46: EPOCH - 30 : training on 601119 raw words (219783 effective words) took 3.3s, 66372 effective words/s
# INFO - 06:05:46: training on a 18033570 raw words (6581170 effective words) took 97.5s, 67522 effective words/s
# Time to train the model: 1.62 mins

# %% [markdown]
# As we do not plan to train the model any further, we are calling init_sims(), which will make the model much more memory-efficient:

# %%
w2v_model.init_sims(replace=True)
# Out:
# INFO - 06:06:09: precomputing L2-norms of word weight vectors

# %% [markdown]
# # Exploring the model
# ## Most similar to:
#
# Here, we will ask our model to find the word most similar to some of the most iconic characters of the Simpsons!

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/0/02/Homer_Simpson_2006.png/revision/latest?cb=20091207194310" alt="drawing" width="130"/>
#
# Let's see what we get for the show's main character:

# %%
help(w2v_model.wv.most_similar)
# Out:
# Help on method most_similar in module gensim.models.keyedvectors:
#
# most_similar(positive=None, negative=None, topn=10, restrict_vocab=None, indexer=None) method of gensim.models.keyedvectors.Word2VecKeyedVectors instance
#     Find the top-N most similar words.
#     Positive words contribute positively towards the similarity, negative words negatively.
#
#     This method computes cosine similarity between a simple mean of the projection
#     weight vectors of the given words and the vectors for each word in the model.
#     The method corresponds to the `word-analogy` and `distance` scripts in the original
#     word2vec implementation.
#
#     Parameters
#     ----------
#     positive : list of str, optional
#         List of words that contribute positively.
#     negative : list of str, optional
#         List of words that contribute negatively.
#     topn : int, optional
#         Number of top-N similar words to return.
#     restrict_vocab : int, optional
#         Optional integer which limits the range of vectors which
#         are searched for most-similar values. For example, restrict_vocab=10000 would
#         only check the first 10000 word vectors in the vocabulary order. (This may be
#         meaningful if you've sorted the vocabulary by descending frequency.)
#
#     Returns
#     -------
#     list of (str, float)
#         Sequence of (word, similarity).

# %%
w2v_model.wv.most_similar(positive=["homer"])
# Out:
# /opt/conda/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('depressed', 0.731344997882843),
#  ('marge', 0.6894108653068542),
#  ('bongo', 0.6707532405853271),
#  ('hammock', 0.6693367958068848),
#  ('terrific', 0.6616975665092468),
#  ('dr_hibbert', 0.6591916084289551),
#  ('sweetheart', 0.6464352607727051),
#  ('suspicious', 0.6443511247634888),
#  ('fault', 0.6398375034332275),
#  ('rude', 0.6373587250709534)]

# %% [markdown]
# _A small precision here:_<br>
# The dataset is the Simpsons' lines of dialogue; therefore, when we look at the most similar words from "homer" we do **not** necessary get his family members, personality traits, or even his most quotable words. No, we get what other characters (as Homer does not often refers to himself at the 3rd person) said along with "homer", such as how he feels or looks ("depressed"), where he is ("hammock"), or with whom ("marge").
#
# Let's see what the bigram "homer_simpson" gives us by comparison:

# %%
w2v_model.wv.most_similar(positive=["homer_simpson"])
# Out:
# [('client', 0.6941632628440857),
#  ('pleased', 0.6938174962997437),
#  ('select', 0.6886515617370605),
#  ('congratulation', 0.6801967024803162),
#  ('governor', 0.6777908802032471),
#  ('sir', 0.6699244976043701),
#  ('council', 0.6663951873779297),
#  ('hutz', 0.6642041206359863),
#  ('waylon', 0.6573621034622192),
#  ('kidnap', 0.6565070748329163)]

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/0/0b/Marge_Simpson.png/revision/latest?cb=20180626055729" alt="drawing" width="150"/>
#
# What about Marge now?

# %%
w2v_model.wv.most_similar(positive=["marge"])
# Out:
# [('homie', 0.7136957049369812),
#  ('grownup', 0.6968562602996826),
#  ('badly', 0.6945315003395081),
#  ('arrange', 0.6927060484886169),
#  ('homer', 0.6894108653068542),
#  ('anyhoo', 0.6857070326805115),
#  ('becky', 0.6836873292922974),
#  ('rude', 0.6800791621208191),
#  ('snuggle', 0.6800758242607117),
#  ('fault', 0.678246796131134)]

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/6/65/Bart_Simpson.png/revision/latest?cb=20180319061933" alt="drawing" width="100"/>
#
# Let's check Bart now:

# %%
w2v_model.wv.most_similar(positive=["bart"])
# Out:
# [('lisa', 0.8484231233596802),
#  ('dr_hibbert', 0.7376271486282349),
#  ('hearing', 0.735810399055481),
#  ('mom', 0.7305068373680115),
#  ('mom_dad', 0.7289035320281982),
#  ('homework', 0.72731614112854),
#  ('upset', 0.7208347320556641),
#  ('creepy', 0.7202103734016418),
#  ('surprised', 0.7019028663635254),
#  ('convince', 0.6958521604537964)]

# %% [markdown]
# Looks like it is making sense!
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/9/9d/Groundskeeper_Willie.png/revision/latest?cb=20130424154035" alt="drawing" width="150"/>
#
# Willie the groundskeeper for the last one:

# %% [markdown]
# ## Similarities:
# Here, we will see how similar are two words to each other :

# %%
help(w2v_model.wv.similarity)
# Out:
# Help on method similarity in module gensim.models.keyedvectors:
#
# similarity(w1, w2) method of gensim.models.keyedvectors.Word2VecKeyedVectors instance
#     Compute cosine similarity between two words.
#
#     Parameters
#     ----------
#     w1 : str
#         Input word.
#     w2 : str
#         Input word.
#
#     Returns
#     -------
#     float
#         Cosine similarity between `w1` and `w2`.

# %%
w2v_model.wv.similarity("moe_'s", 'tavern')
# Out:
# 0.91360706

# %% [markdown]
# Who could forget Moe's tavern? Not Barney.
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/6/6c/MaggieSimpson.PNG/revision/latest?cb=20180314210204" alt="drawing" width="100"/>

# %%
w2v_model.wv.similarity('maggie', 'baby')
# Out:
# 0.7047698

# %% [markdown]
# Maggie is indeed the most renown baby in the Simpsons!

# %%
w2v_model.wv.similarity('bart', 'nelson')
# Out:
# 0.5848839

# %% [markdown]
# Bart and Nelson, though friends, are not that close, makes sense!
#
# ## Odd-One-Out:
#
# Here, we ask our model to give us the word that does not belong to the list!
#
# Between Jimbo, Milhouse, and Kearney, who is the one who is not a bully?

# %%
help(w2v_model.wv.doesnt_match)
# Out:
# Help on method doesnt_match in module gensim.models.keyedvectors:
#
# doesnt_match(words) method of gensim.models.keyedvectors.Word2VecKeyedVectors instance
#     Which word from the given list doesn't go with the others?
#
#     Parameters
#     ----------
#     words : list of str
#         List of words.
#
#     Returns
#     -------
#     str
#         The word further away from the mean of all words.

# %%
w2v_model.wv.doesnt_match(['jimbo', 'milhouse', 'kearney'])
# Out:
# 'milhouse'

# %% [markdown]
# Milhouse of course!
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/9/91/Milhouse_Van_Houten_2.png/revision/latest?cb=20180429212659" alt="drawing" width="150"/>
#
# What if we compared the friendship between Nelson, Bart, and Milhouse?

# %%
w2v_model.wv.doesnt_match(["nelson", "bart", "milhouse"])
# Out:
# 'nelson'

# %% [markdown]
# Seems like Nelson is the odd one here!
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/4/40/Picture0003.jpg/revision/latest?cb=20110623042517" alt="drawing" width="200"/>
#
# Last but not least, how is the relationship between Homer and his two sister-in-laws?

# %%
w2v_model.wv.doesnt_match(['homer', 'patty', 'selma'])
# Out:
# 'homer'

# %% [markdown]
# Damn, they really do not like you Homer!
#
# ## Analogy difference:
# Which word is to woman as homer is to marge?

# %%
w2v_model.wv.most_similar(positive=["woman", "homer"], negative=["marge"], topn=3)
# Out:
# [('man', 0.6114931702613831),
#  ('admire', 0.5659395456314087),
#  ('people', 0.5597838163375854)]

# %% [markdown]
# "man" comes at the first position, that looks about right!
#
# Which word is to woman as bart is to man?

# %%
w2v_model.wv.most_similar(positive=["woman", "bart"], negative=["man"], topn=3)
# Out:
# [('lisa', 0.7107527256011963),
#  ('surprised', 0.6350199580192566),
#  ('mom', 0.6176263093948364)]

# %% [markdown]
# Lisa is Bart's sister, her male counterpart!
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/5/57/Lisa_Simpson2.png/revision/latest?cb=20180319000458" alt="drawing" width="100"/>

# %% [markdown]
# ### t-SNE visualizations:
# t-SNE is a non-linear dimensionality reduction algorithm that attempts to represent high-dimensional data and the underlying relationships between vectors in a lower-dimensional space.<br>
# Here is a good tutorial on it: https://medium.com/@luckylwk/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# Our goal in this section is to plot our 300 dimensions vectors into 2 dimensional graphs, and see if we can spot interesting patterns.<br>
# For that we are going to use t-SNE implementation from scikit-learn.
#
# To make the visualizations more relevant, we will look at the relationships between a query word (in <font color='red'>**red**</font>), its most similar words in the model (in <font color="blue">**blue**</font>), and other words from the vocabulary (in <font color='green'>**green**</font>).

# %%
def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=50).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %% [markdown]
# Code inspired by: [[2]](#References:)
#
# ## 10 Most similar words vs. 8 Random words:
# Let's compare where the vector representation of Homer, his 10 most similar words from the model, as well as 8 random ones, lies in a 2D graph:

# %%
tsnescatterplot(w2v_model, 'homer', ['dog', 'bird', 'ah', 'maude', 'bob', 'mel', 'apu', 'duff'])
# Out:
# /opt/conda/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# Interestingly, the 10 most similar words to Homer ends up around him, so does Apu and (sideshow) Bob, two recurrent characters.
#
# ## 10 Most similar words vs. 10 Most dissimilar
#
# This time, let's compare where the vector representation of Maggie and her 10 most similar words from the model lies compare to the vector representation of the 10 most dissimilar words to Maggie:

# %%
tsnescatterplot(w2v_model, 'maggie', [i[0] for i in w2v_model.wv.most_similar(negative=["maggie"])])

# %% [markdown]
# Neat! Maggie and her most similar words form a distinctive cluster from the most dissimilar words, it is a really encouraging plot!
#
# ## 10 Most similar words vs. 11th to 20th Most similar words:
#
# Finally, we are going to plot the most similar words to Mr. Burns ranked 1st to 10th versus the ones ranked 11th to 20th:
#
# (PS: Mr. Burns became mr_burn after the preprocessing)

# %%
tsnescatterplot(w2v_model, "mr_burn", [t[0] for t in w2v_model.wv.most_similar(positive=["mr_burn"], topn=20)][10:])

# %% [markdown]
# As we can see, and that is very nice, all the 20 words are forming one cluster around Mr. Burns.
#
# # Final Thoughts
#
# I hope you found this tutorial useful and had as much fun reading it as I had writing it. Please do not hesitate to leave any comments, questions or suggestions you might have. See you around!
#
# Also, please check [Supportiv](http://www.supportiv.com) around! (Simpson-ized logo)
#
# <img src="https://fontmeme.com/permalink/180904/cc3d27a8aaa88189e764ee9d02331d0d.png" alt="drawing" width="500"/>
#
#
# # Materials for more in depths understanding:
# * Word Embeddings introduction: https://www.analyticsvidhya.com/blog/2017/06/word-embeddings-count-word2veec/
# * Word2Vec introduction: https://skymind.ai/wiki/word2vec
# * Another Word2Vec introduction: http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
# * A great Gensim implentation tutorial: http://kavita-ganesan.com/gensim-word2vec-tutorial-starter-code/#.W467ScBjM2x
# * Original articles from Mikolov et al.: https://arxiv.org/abs/1301.3781 and https://arxiv.org/abs/1310.4546
#
#
# # Acknowledgements
#
# * [Pouria Mojabi](https://www.linkedin.com/in/pouria-mojabi-1873615/), co-fouder of Supportiv Inc.
#
# # References:
# * [1]. Neural Net picture: McCormick, C. (2016, April 19). Word2Vec Tutorial - The Skip-Gram Model. Retrieved from http://www.mccormickml.com
# * [2]. Aneesha Bakharia Medium article: https://medium.com/@aneesha/using-tsne-to-plot-a-subset-of-similar-words-from-word2vec-bb8eeaea6229
#
# # End
